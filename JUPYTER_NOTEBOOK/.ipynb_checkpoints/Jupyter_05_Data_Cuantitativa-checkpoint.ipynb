# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
listings = pd.read_csv("listings.csv")

# %%
listings
# Out:
#              id                                              name    host_id  \
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
plt.hist(listings['price'], bins = np.arange(0,1100,40)) #Determinar la distribución cuantitativa de los precios (histograma)
plt.xlabel('price(in US Dollars)')
plt.show()

# %%
plt.scatter(x = listings['price'], y = listings['number_of_reviews']) #Determinar la distribución cuantitativa de los precios en función de los reviews
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.show()

# %%
plt.scatter(x = listings['price'], y = listings['number_of_reviews']) #Restringimos el eje x a 1100 con xlim
plt.xlabel('price')
plt.xlim(0,1100)
plt.ylabel('number of reviews')
plt.show()

# %%
plt.scatter(x = listings['price'], y = listings['number_of_reviews'], s=5) #Bajamos el tamaño de los punto con s
plt.xlabel('price')
plt.xlim(0,1100)
plt.ylabel('number of reviews')
plt.show()

# %%
import pandas as pd    #Tipos de alojamiento por barrio (top 10)
import matplotlib.pyplot as plt

# Agrupa los datos por barrio y tipo de alojamiento
df_grupo = listings.groupby(['neighbourhood', 'room_type']).size().unstack(fill_value=0)

# Sumar las cantidades por barrio y filtrar los 10 barrios más representativos
top_neighbourhoods = df_grupo.sum(axis=1).nlargest(10).index
df_top = df_grupo.loc[top_neighbourhoods]

# Genera el gráfico de barras horizontales
df_top.plot(kind='barh', stacked=True, figsize=(10, 6))
plt.title('Tipos de alojamiento por barrio (Top 10)')
plt.xlabel('Cantidad')
plt.ylabel('Barrio')
plt.legend(title='Tipo de alojamiento', bbox_to_anchor=(1, 1))
plt.show()
